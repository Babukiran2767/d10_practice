# %%
import numpy as np
import time

l = list ( range(100000000))
start = time.time()
res = [x*2 for x in l]
list_time = time.time()-start

T = np.arange(100000000)
start = time.time()
res = T*2
np_time = time.time()


list_time,np_time
# Out:
# (7.019392728805542, 1781797150.3889968)

# %%
# # From list
# arr1 = np.array([1,2,3,4,5]) # single demnsional array
# arr1
# # Built in method
# zero = np.zeros((3,3))
# zero
# one = np.ones((3,3))
# oney 

# ar = np.arange((10))  #0,1,2,,3....9
# lin = np.linspace
# arr1


arr = np.array([[1,2,3],[4,5,6]])
k = arr + 10
k
# Out:
# array([[11, 12, 13],
#        [14, 15, 16]])
